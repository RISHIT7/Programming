# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('ggplot')

# %%
DATA = pd.read_excel('../HUL261/Id_Affect.xlsx')

# %%
DATA = pd.DataFrame(DATA)
DATA.head()
# Out:
#       Unnamed: 0  Sweet Bitter   Sour  Salty   Joy Sadness Surprise  Fear  \
# 0  Soundtrack_Id      %      %      %      %  Mean    Mean     Mean  Mean
# 1              1  46.43  20.24  10.71  22.62  2.74    4.15     2.25  2.15
# 2              2   48.1  30.38   8.86  12.66  2.76    4.51     2.32     2
# 3              3  36.99  24.66   13.7  24.66  2.53    4.56     2.78  2.05
# 4              4   19.1  50.56   8.99  21.35  2.15    4.35     3.25  2.78
#
#   Anger Valence (P) Arousal (P) Familiarity Valence (F) Arousal (F)
# 0  Mean        Mean        Mean        Mean        Mean        Mean
# 1  1.93        4.77         3.3        3.69        4.74        2.88
# 2  1.75        4.71        3.72        3.73        4.71        3.19
# 3  2.04        4.63        4.11        4.63        4.38         3.6
# 4  2.35        4.19        4.28        3.82        3.88        4.34

# %%
DATA = DATA.drop(columns='Unnamed: 0')

# %%
DATA.head()
# Out:
#    Sweet Bitter   Sour  Salty   Joy Sadness Surprise  Fear Anger Valence (P)  \
# 0      %      %      %      %  Mean    Mean     Mean  Mean  Mean        Mean
# 1  46.43  20.24  10.71  22.62  2.74    4.15     2.25  2.15  1.93        4.77
# 2   48.1  30.38   8.86  12.66  2.76    4.51     2.32     2  1.75        4.71
# 3  36.99  24.66   13.7  24.66  2.53    4.56     2.78  2.05  2.04        4.63
# 4   19.1  50.56   8.99  21.35  2.15    4.35     3.25  2.78  2.35        4.19
#
#   Arousal (P) Familiarity Valence (F) Arousal (F)
# 0        Mean        Mean        Mean        Mean
# 1         3.3        3.69        4.74        2.88
# 2        3.72        3.73        4.71        3.19
# 3        4.11        4.63        4.38         3.6
# 4        4.28        3.82        3.88        4.34

# %%
def print_foo(data_x, data_y, ax):
    y_ = DATA[data_x][1:]
    z_ = DATA[data_y][1:]
    ax.set_label(data_y + ' vs ' + data_x)
    ax.set_xlabel(data_y)
    ax.set_ylabel(data_x)
    ax.scatter(y_, z_)

# %%
fig, axes = plt.subplots(4, 2, figsize = (12, 16))

ax = axes[0][0]
print_foo('Fear', 'Anger', ax)

ax = axes[0][1]
print_foo('Fear', 'Sweet', ax)

ax = axes[1][1]
print_foo('Joy', 'Bitter', ax)

ax = axes[1][0]
print_foo('Sadness', 'Bitter', ax)

ax = axes[2][0]
print_foo('Bitter', 'Fear', ax)

ax = axes[2][1]
print_foo('Sour', 'Arousal (F)', ax)

ax = axes[3][0]
print_foo('Anger', 'Joy', ax)

ax = axes[3][1]
print_foo('Sweet', 'Valence (P)', ax)
