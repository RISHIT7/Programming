# %%
import pandas as pd
import seaborn as sns
sns.set_theme(style="darkgrid")
# Out:
# c:\Users\rishi\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
index = []
for i in range(0, 100):
    index.append(i*20 + 5)
len(index)
# Out:
# 100

# %%
data1 = pd.read_csv('seconds1.csv', index_col=False)
data2 = pd.read_csv('seconds2.csv', index_col=False)
data3 = pd.read_csv('seconds3.csv', index_col=False)
data4 = pd.read_csv('seconds4.csv', index_col=False)
data5 = pd.read_csv('seconds5.csv', index_col=False)
data = (data1 + data2 + data3 + data4 + data5) / 5
data.set_index(pd.Index(index), inplace=True)
data.dropna(inplace=True, axis=1)
data
# Out:
#       ij_app   ji_app   ij_inp   ji_inp
# 5     0.0006   0.0000   0.0002   0.0000
# 25    0.0006   0.0002   0.0008   0.0006
# 45    0.0090   0.0008   0.0014   0.0014
# 65    0.0076   0.0058   0.0062   0.0026
# 85    0.0058   0.0030   0.0040   0.0038
# ...      ...      ...      ...      ...
# 1905  7.7682   6.3616   7.0372   6.0608
# 1925  7.7856   6.9492   7.7562   6.9592
# 1945  8.4680   8.1814   8.4928   8.2568
# 1965  8.9164   7.2248   8.2454   7.6136
# 1985  9.6324   7.5008   8.8154   7.8376
#
# [100 rows x 4 columns]

# %%
sns.lineplot(data=data, dashes=False, markers=False, palette="tab10", linewidth=2).set_xlabel('Matrix Size')
# Out:
# Text(0.5, 0, 'Matrix Size')

# %%
n = 200

# %%
index = []
for i in range(0, n):
    index.append(i*20 + 5)
len(index)
# Out:
# 200

# %%
data_5000 = pd.read_csv('seconds_5000.csv', index_col=False)[:n]
data_5000.set_index(pd.Index(index), inplace=True)
data_5000.dropna(inplace=True, axis=1)
data_5000.head()
# Out:
#     ij_app   ji_app   ij_inp   ji_inp
# 5    0.001    0.001    0.000    0.000
# 25   0.001    0.001    0.002    0.002
# 45   0.004    0.003    0.003    0.003
# 65   0.009    0.005    0.006    0.006
# 85   0.011    0.007    0.011    0.010

# %%
data_5000.plot()
# Out:
# <AxesSubplot:>
