# %% [markdown]
# ## Time complexity

# %% [markdown]
# O() <br>
# $\theta()$ <br>
# $\Omega()$ <br>

# %% [markdown]
# O(logn) O(sqrt(n)) O(n) O(nlogn) O(nsqrt(n)) ... O(exp)

# %%
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(1, 10, 100)
y1 = x*x
y2 = x*np.log(x)

# %%
plt.plot(x, y1)
plt.plot(x, y2)
